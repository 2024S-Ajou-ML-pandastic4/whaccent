# %% [markdown]
# <a href="https://colab.research.google.com/github/2024S-Ajou-ML-pandastic4/whaccent/blob/feature%2Fdataset/baseline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from typing import List
import io
import os
import pandas as pd
import urllib.request
import tarfile
import time
import http
import types
from torch.utils.data import Dataset


# Headers:  id, audio_path, country, transcription, duration
class Pandastic4Dataset(Dataset):
    def __init__(
        self,
        root="../pandastic4_dataset",
        transform=None,
        train: bool = True,
        random_state: int = 201820766,
    ):
        self.root = root
        self.transform = transform
        self.train = train
        self.random_state = random_state

        self.data: pd.DataFrame = None
        self.download()

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        sample = self.data.iloc[idx]
        audio_path = os.path.join(self.root, sample["audio_path"])
        country = sample["country"]
        transcription = sample["transcription"]
        # if self.transform:
        #     audio = self.transform(audio)
        return audio_path, country, transcription

    def _check_exists(self) -> bool:
        if not self._try_load_manifest():
            return False

        for audio_path in self.data["audio_path"]:
            if not os.path.isfile(os.path.join(self.root, audio_path)):
                return False
        return True

    def _try_load_manifest(self) -> bool:
        manifest_paths = [
            os.path.join(
                self.root,
                "output",
                f'{country}_{"train" if self.train else "test"}.csv',
            )
            for country in ["KR", "US", "GB"]
        ]

        manifest_exist = all(os.path.isfile(path) for path in manifest_paths)
        if not manifest_exist:
            return False
        manifests = [pd.read_csv(manifest_path) for manifest_path in manifest_paths]
        self.data = (
            pd.concat(manifests)
            .sample(frac=1, random_state=self.random_state)
            .reset_index(drop=True)
        )

        return True

    def download(self) -> None:
        if self._check_exists():
            return
        os.makedirs(self.root, exist_ok=True)
        url = "http://mldataset.ddns.net/f/dae3e2b1a5374690a80c/?dl=1"
        target_path = os.path.join(self.root)

        stream = urllib.request.urlopen(url)
        length = stream.getheader("content-length")
        stream._length = int(length)
        stream._downloaded = 0
        stream._started_at = time.time()
        stream._last_printed = stream._started_at
        stream._print_interval = 5

        def read_with_progress(self: http.client.HTTPResponse, size):
            self._downloaded += size
            now = time.time()
            if now - self._last_printed > self._print_interval:
                speed_mps = self._downloaded / (now - self._started_at) / 1024 / 1024
                print(
                    f"Downloading: {self._downloaded}/{self._length}\t{100*self._downloaded/self._length:.0f}%\t{speed_mps:.1f}MB/s"
                )
                self._last_printed = now
            return http.client.HTTPResponse.read(self, size)

        stream.read = types.MethodType(read_with_progress, stream)

        tar_file = tarfile.open(fileobj=stream, mode="r|gz")
        tar_file.extractall(path=target_path)
        assert self._check_exists()

# %%
from torch.utils.data.dataloader import DataLoader

dataset = Pandastic4Dataset()
data = DataLoader(dataset, batch_size=64)
for _, country, transcription in data:
    print(country, transcription)
# Out:
# 6810
# ('GB', 'GB', 'KR', 'US', 'US', 'US', 'US', 'GB', 'KR', 'KR', 'KR', 'KR', 'KR', 'KR', 'GB', 'US', 'US', 'KR', 'GB', 'GB', 'GB', 'GB', 'KR', 'US', 'GB', 'US', 'KR', 'GB', 'GB', 'KR', 'GB', 'KR', 'KR', 'GB', 'KR', 'KR', 'US', 'US', 'KR', 'GB', 'US', 'KR', 'US', 'KR', 'US', 'GB', 'US', 'GB', 'KR', 'GB', 'US', 'KR', 'KR', 'US', 'KR', 'GB', 'KR', 'US', 'KR', 'KR', 'US', 'KR', 'US', 'KR') ('He stopped as abruptly as she had done.', 'Still, she was on her own, and not very brave.', ' I left some donuts on the side of the road.', "but he didn't see none then the circus started an b'lieve me it was some circus jo hadn't had much action for some time", 'with it and that though they might peck and mend at the body he had received his final orders', 'daring vigorous and muscular fish armed with prickles on its head and stings on its fins a real scorpion measuring two to three meters the ruthless enemy', 'i have refused refused why for reasons of my own', 'That might be wise, given our record.', ' Unfortunately, irises are my most cherished flowers.', " You can join us for a buffet if you'd like.", " I'm so sorry to tell you but the magazine can't take it out of this building.", " Susan's answer over the phone was very callous.", ' My advisor is being economical with the truth.', ' yes but they will get used to it soon', 'But there was a heaviness in his response.', "it's by virtue of feverish toil that you have become what you are being endlessly industrious is the best road for you to the heights", 'and you stooped to pick up whatever it was that had been thrown away', " The husband is paying for his wife's clothes.", 'He pointed to someone sitting in the front row.', 'Before him is a plan of a building.', "'Did we leave it in the bedroom?’", 'Instruction is a sort of specific leadership.', ' Please let the letterman lead.', 'the experiment was repeated on other subjects in all cases with the same result', "But it's people who convert that into a successful business.", 'that the physician alone is called to administer psychotherapeutic work but that he needs a thorough psychological training besides his medical one but the interest of the community is not only a negative one', ' You can choose the flavor on the list has a lot of flavors.', "'A bit rapid, but not unduly so under the circumstances.’", 'They were both too nice for their own good.', ' oh I drink milk twice a day', 'It was all a very sudden call to action.', ' I like dogs and cats.', ' the division know that ice cream chills mostly affects the mouth only', "‘Well, I can't pretend I know what that means.’", ' I miss the girl I met in elementary school the most because I feel like she is my first love.', ' The sailors will sail across the Atlantic by ship.', 'everything is as you left it but it glided about the room with the grace of a fairy and the tenderness of an angel', 'i fought with aunt jane like a pirate and it quite won her heart when she died she left me all she had in the world look at that now said the major wonderingly which turned out to be nothing at all continued patsy', ' This lasagna is delicious.', '‘What a fantastic view you have from here.’', 'a moderate sense of humour and could tell a good story when the occasion required he could talk races with hurstwood', ' Congratulations on a job well done.', 'as that last glass of champagne we drank together when i said and so let us drink out the rest of our lives', ' The challenges of climate change and energy security have propelled Asian nations to increasingly embrace investment in renewable energy.', 'make one knit two together knit three make one knit one make one knit three', 'The argument cannot be stopped at this simple point, however.', 'polished beauty of diction political storm and stress position of titular command', "I didn't know about your father, about making you work.", " What a wonderful gift you gave to help others be more empathetic and sensitive to friends and family who don't know what to say. ...
# ('GB', 'KR', 'US', 'GB', 'GB', 'US', 'KR', 'US', 'US', 'US', 'US', 'GB', 'KR', 'US', 'US', 'KR', 'KR', 'KR', 'US', 'US', 'US', 'GB', 'KR', 'KR', 'KR', 'US', 'GB', 'KR', 'GB', 'US', 'KR', 'US', 'KR', 'KR', 'KR', 'US', 'GB', 'US', 'GB', 'KR', 'US', 'GB', 'GB', 'US', 'KR', 'US', 'US', 'US', 'US', 'US', 'GB', 'KR', 'KR', 'KR', 'GB', 'KR', 'KR', 'US', 'KR', 'GB', 'KR', 'GB', 'GB', 'GB') ("‘Well, I think it's about time you did some work.'", " I'm not 100% sure.", "robinson jerked his head toward the window i've been watching the preparations out there", 'I am ready to give it a go.', 'Man and creation are more than flesh and rock.', 'wherefore their idea also necessarily', ' The cooperation between the citizens and animal protection groups helped save the endangered animals.', 'horsemen spearsmen pikemen a full thousand of them at my right were the scattered company that had come from the tunnel entrance threescore or more there seemed a spell upon them', 'he held in his lap a tiny maltese dog with a tiny silver collar and bell and when he had a hand unused by cigar or coffee cup it rested on this small parcel of animal warmth', 'carlini ate and drank as if nothing had happened the bandits looked on with astonishment at this singular conduct until they heard footsteps they turned round', 'me they stripped like a slave they led me through the city and the people mocked me', "I'm sure she will feel the same.", ' The balloons floated away along with all my hopes and dreams.', 'he remarked sadly the youth had a thought that it would not be handsome for him to freely condemn other men he made an attempt to restrain himself but the words upon his tongue were too bitter', 'in these few bold strokes one who knew him by virtue of close art and race kinship presents an incomparable outline sketch of the polish tone poet', ' Tissues tear frequently and easily. ', ' Vaughn was passionate about combating poverty and sexism.', ' Michelangelo’s sculpting abilities soon earned him acclaim.', "it's impossible i should wait for you missus touchett answered", "our selling the three hundred cakes corrected rebecca you did as much as i no i didn't rebecca randall i just sat at the gate and held the horse yes but whose horse was it that took us to north riverboro", 'you set your face against all the fair ones but i succeeded in turning the conversation into another channel', "'I do hope there wasn't a disagreement.’", ' The old admiral revels in its absolute authority.', ' Jamie was astonished to see that the door was already open.', ' You should acquire your credit from our company by purchasing our merchandise.', 'this time she changed the turnip into a magpie flutter from tree to tree chattering bird said she till you come to ratibor my love', 'Thinking that something will happen does not make it happen.', ' The detective was able to deduce the criminal’s identity.', "‘There is little of that left now, she says.'", 'tromp succeeded by expert seamanship in holding off the enemy and conducting his convoy with small loss into safety', ' How do you celebrate Easter?', 'into a corps no matter whether he loves the service or no being once in it he acts as if he did and takes every step to shew himself a man of prowesse', ' For more information, stop by the student council office.', ' These days, married children often prefer to live on their own.', " Don't worry about it as of weather cast it will be sunny.", 'she would break off in the midst of the song', 'I take a deep breath, trying to wake myself up.', 'and had gone to bed and to sleep she called the maid and questioned her mademoiselle eugenie said the maid', 'So much to see so little time!', ' The oversized villain bears a rather uninspired resemblance to Frankenstein.', 'the prince meantime stood in the water staring and forgetting to get out but the princess disappearing he scrambled on shore and went in the direction of the tree', 'The proxy need not be a member.', 'The building had been set aligh ...
# ('GB', 'KR', 'KR', 'US', 'KR', 'KR', 'US', 'KR', 'KR', 'KR', 'US', 'KR', 'US', 'KR', 'US', 'US', 'US', 'GB', 'GB', 'KR', 'US', 'US', 'GB', 'GB', 'US', 'KR', 'GB', 'KR', 'US', 'US', 'KR', 'KR', 'KR', 'US', 'KR', 'KR', 'US', 'KR', 'US', 'GB', 'KR', 'US', 'US', 'KR', 'US', 'GB', 'KR', 'US', 'GB', 'US', 'KR', 'US', 'GB', 'US', 'GB', 'KR', 'GB', 'US', 'US', 'US', 'KR', 'GB', 'US', 'US') ("I don't know why I said that.", ' Anthropologists believe these two factors contributed to the decline of their culture.', ' While on the bus tour, you will discover new alleys and corners of the capital.', 'i slept badly the events that had happened since my arrival in england had excited me i suppose now and then in the wakeful hours of the night i thought of cristel with some anxiety', ' A national survey estimated that 50% of all men said heart problems would motivate them the most.', ' A town can contain several villages.', "it suddenly struck peter that if he hadn't seen her do it he wouldn't have known she was there", ' My favorite season is winter. Because I can eat warm bungeoppang and hoppang.', ' The floor had been marred by scratches and scuff marks.', " Children's are inside a tent and looking at the bubbles.", "they shouted there's another of those saint simonians and they wanted to kill him now he had under his arm a volume of the memoirs of the duc de saint simon", ' It was raining cats and dogs in the middle of December.', 'but it was of no use he declined to move out of a walk', ' You are a member of your family, a player on the baseball team, and a student in your school.', 'to find someone standing directly over him loudly and insistently calling his name', 'so for the second time the living met the dead and the law watched hopefully', 'are any other beings ever found in such masses but vermin aimless staring vacant minded look at them', 'There was an unkempt look about him.', 'From out there, however, the view is very different.', " It's quite far. I don't think I can walk from here to there.", 'the door was barred from top to bottom', 'ye kin wear it when ye get among the swells i lost the paper when i was tryin to get through them fellers downstairs', "We're not even a third of the way there.", 'Quite possibly it reverted to its former use.', 'was white and clear against the dark background of spruces we were woefully tired but we could not sit down because the grass was reeking with dew the family ghost only appears in daylight said the story girl', ' The dentist says I’ll have to wear the braces for the next twelve months.', 'Anna had dropped her voice to a whisper.', ' Crocuses herald the advent of spring.', 'if such a society were formed it would necessarily take many problems of the race under consideration and the officials at washington and in the field are sensitive to criticism', 'faugh said elzevir tis a poor beast has lost his foothold it was an ill omen enough and i said as much beseeching him to make his own way up the zigzag', ' Construction began in 1862, but the outbreak of the Civil War slowed progress considerably on the Union Pacific line.', ' The City Hall is situated on the next block on your left.', ' Maybe he is confusing you and the other in the office.', "only then would he venture to skip to the water's edge and plunge in to tell the truth master meadow mouse always felt safer when one of the muskrat family happened to be taking a swim at the same time", ' Many residents from low-lying areas have shifted to storm shelters as water sloshed through their homes.', ' Vulcanized rubber was used to make belts, bicycle tires, and rubber parts for machinery. ', 'that she should have gone the longest way round to florence in order to spend a few weeks with her invalid son', ' Something like a weight on our chest.', 'at first under different animal shapes since that time partly from habit and partly to amuse ourselves we have continued to transform ourselves and it was in this way that i got to know you how e ...
# ('US', 'GB', 'US', 'GB', 'KR', 'GB', 'US', 'GB', 'US', 'US', 'US', 'US', 'KR', 'GB', 'GB', 'US', 'GB', 'KR', 'GB', 'US', 'KR', 'GB', 'GB', 'GB', 'KR', 'KR', 'KR', 'GB', 'US', 'GB', 'KR', 'US', 'GB', 'KR', 'GB', 'US', 'GB', 'GB', 'GB', 'US', 'US', 'KR', 'GB', 'GB', 'GB', 'US', 'GB', 'US', 'KR', 'US', 'KR', 'GB', 'KR', 'KR', 'US', 'US', 'US', 'KR', 'GB', 'GB', 'KR', 'GB', 'GB', 'US') ('having finished the edifice which rose at least six feet into the air', 'This was an essential function, but limited to scope.', 'certainly they must make the amalfi drive', 'Exactly, and let us not forget this either.', ' When I read the list of ingredients, my stomach turned.', 'No wonder we cry when we do it.', 'truly and honest patty turned it over and pointed to the initials on the end', 'The whole operation is run from the van.', 'the very next morning she put on all her finery and thought that now at least that disagreeable parrot could find no fault with her appearance and she listened eagerly when she heard the starling say', 'i kissed her shoes and the ankles above her shoes when the hem of her garment touched my face i trembled when after two years of that life', "we shall have to do away with jesus quietly someone said yes the others agreed we can't wait till the day of the passover if we should do anything to him on that day there would be a riot", 'that this judgment of the academy be placed upon the records these three propositions put to vote are adopted', ' At school, most of my friends tried to be nice about my leg cast. ', 'Another successful choice would be a golden wedding anniversary.', '"Please excuse me I must begin my work."', "whatever else you called her and no one could call grammont blood all ordinary fluid old grammont had never had any delusions about lake if lake's father hadn't been a big man", 'The budget is therefore set up anew each year.', ' Did I hurt your feelings?', 'Here again there was a fundamental mistake.', 'and replaceable structures indeed both these two people found themselves thinking in this fashion with an unwonted courage and freedom because the other one had been disposed to think in this fashion before', ' Yes, just across the road.', 'He was a clown and a genius.', '‘So you see you can never be too careful.’', 'The first four were hardly inconsistent with his career.', ' The fool must be out of his mind to ask such stupid things.', ' A dazzling bird humming outside dazzling window.', ' Seoul, the capital city of South Korea, stays the 10th most expensive location in the world.', '‘I was sure these were in there,’ he said.', 'so that to bring him round again ever so little cost me more than six hundred eggs', '"If you do, the impossible will start to seem probable."', ' The fly flew onto the sticky paper.\t', "and saying something to his companion with a look of utter disgust probably thought amory what he said was my god aren't people horrible never before in his life had amory considered poor people", 'The question was out before she could bite it back.', ' The snow-covered path was no help in finding his way out of the back-country.', 'Submission is at the core of the problem.', 'the red sun appeared for an instant from under a cloud and its last rays glittered brightly along the river over the reeds on the watch tower', '‘How long is this all going to take?’', 'You may wonder: Who am I to set myself up?', "‘Could you get him to the telephone?'", "they have merely gone to work in a business like manner and used their wits and common sense in educating the voters really my dears i'm more proud of you today than i've ever been before he concluded", 'based the royal decision the lord chancellor added in a postscript', ' The only clue to what might have happened was the word “Croatoan” carved into a post.', 'This is part of the hidden history of education.', 'And doubly good where pleasure and benefit coincide.', 'So you did, and used up a little more time.', 'you must make a dream whirl around  ...
# ('US', 'KR', 'KR', 'KR', 'KR', 'GB', 'KR', 'KR', 'US', 'KR', 'US', 'GB', 'US', 'US', 'US', 'GB', 'US', 'KR', 'KR', 'GB', 'US', 'GB', 'US', 'US', 'GB', 'GB', 'US', 'KR', 'US', 'GB', 'KR', 'KR', 'US', 'US', 'US', 'GB', 'KR', 'KR', 'US', 'US', 'GB', 'US', 'KR', 'KR', 'US', 'GB', 'GB', 'US', 'KR', 'US', 'US', 'KR', 'KR', 'US', 'GB', 'KR', 'US', 'KR', 'US', 'US', 'KR', 'US', 'US', 'KR') ('the wonderful right bank of this river all loaded down with country homes and passed by the forts to salutes from their biggest cannons', ' Who was on the opposite side?', ' Williams went on a whiskey diet and immediately lost three days.', " The 'frills' that provide the breadth of a well-rounded education are no longer ‘served.'", ' Charlene lived on Monkey Jungle Road and that seemed to explain all of her strangeness.', "'At least it will be all downhill!’", ' Look up the definition in the dictionary.', ' Please let the letterman lead.', 'to bid my wife and children adieu and', ' There was complete silence in the living room.', 'and in about a quarter of an hour she returned bearing the pail which was now partly filled with milk as she walked along', '‘Go to bed now, father,’ Grace said.', 'to know how much the shadow uses up the mirror and to put a price on it and by five hundred thousand devils to make the traveller pay for everything', 'there was some one else he ought to have married and i knew it and i told her i would not hinder it and i went away that was when you first saw me', "many shacks and camps at first mistaken for the white men's houses were found to be occupied by natives they were a drunken rascally rabble spending their gains from the sale of fish and oil", 'But I had not been raised to be merely decorative.', 'and when two or three years later there was a general insolvency among them occasionally large losses to new york merchants and in some cases failure the tappans were saved by having no southern debts', " The employees weren't able to endure the complaints and the operating difficulties.", " A man is giving a woman a box of vegetables. The woman seems happy to receive the box. I think the woman was working because she's wearing an apron.", 'It will always be in his mind.’', "and showing that scientist some of the manufactured diamonds getting our wireless apparatus in shape answered the lad i should have done it before but i had so much to do that i couldn't get at it", 'You had no idea what was going on.', 'published by sidis and goodhart in their important work on multiple personality we read that when the patient first recovered consciousness and', "tis better to be vile than vile esteem'd when not to be receives reproach of being and the just pleasure lost which is so deem'd not by our feeling but by others seeing", 'What will you be going for, senator?', 'You forget that I was an academic.', 'a young man who expected to have his things packed or unpacked for him by a servant when he travelled', ' I was thinking of going around your place.', 'keeping to its northerly heading it followed the long windings of south america by then we had fared sixteen thousand leagues since coming on board in the seas of japan', 'My reply was, ‘No, but I feel it too!’', ' Leadership is an invisible strand as mysterious as it is powerful.', ' Divide the highlighted sentence into meaningful parts to grasp its correct meaning.', 'but reflection convinced them that it was not only right to assist men in efforts to obtain their liberty when unjustly held in bondage but a duty abolitionists white and colored both in slave and free states', "rummaging his mother's desk some time afterwards found the gloves neatly folded up", 'we should miss the sliding bookcases and picture stands', "'Then we can say a proper farewell.’", ' Many tourists believed e-scooters would be a cheap transportation method for sightseeing.', ' As the inundation receded, farmers plowed and planted crops to fertile soil called silt.', 'look at me as long as you like my  ...
# ('GB', 'US', 'US', 'GB', 'US', 'US', 'GB', 'KR', 'GB', 'GB', 'KR', 'US', 'KR', 'KR', 'GB', 'GB', 'KR', 'GB', 'KR', 'US', 'KR', 'US', 'KR', 'GB', 'KR', 'GB', 'KR', 'US', 'GB', 'US', 'US', 'US', 'GB', 'US', 'GB', 'US', 'KR', 'US', 'GB', 'GB', 'KR', 'GB', 'KR', 'US', 'US', 'GB', 'US', 'KR', 'US', 'GB', 'US', 'KR', 'GB', 'GB', 'KR', 'KR', 'GB', 'KR', 'US', 'KR', 'US', 'GB', 'US', 'US') ('There was a knock at the front door.', 'now leif settled down in greenland and became a great man there he was so busy and he grew so rich that he did not think of going to wineland again but people could not forget his story', 'several pipes that had been extinguished were lighted again', "‘You don't bother to try and prove yourself.'", 'ghosts not only have appallingly long memories but they possess a mean advantage over the living in that they have once been mortal', "and i wonder myself why when a family loses its money people always say the daughters ought to go and be stenographers it's curious", "'If so, it was not by intention.’", ' In Finland, people must know how to read in order to get married.', 'Someone had to knock some sense into me', 'Let me try to explain what I am getting at.', ' Her meticulous recollection of events and account suggests she may have kept a record of the events.', 'well said andrea', " Don't waste my time trying to get my sympathy.", ' Delays in processing passport applications are forcing hundreds of families in Wales to cancel their holidays.', '‘Not because of your lovely mouth, my dear.’', 'I had never been on a glacier before.', ' Medicine showed a consistently higher employment rate for its college graduates.', "You didn't like it any more than I did.", " They're out there.", 'from insulting or wronging the people of other nations but they always ardently advocate that we in our turn shall tamely submit to wrong and insult from other nations', ' the gulabo program is the provide small villages with mother and facet ease', 'well what has this bandit to do with the order i have given the coachman to leave the city by the porta del popolo', ' It could be the biggest mistake you ever make.', 'So my being nice to him is ridiculous.', ' Husbands who complain about their wives’ spending habits may be afraid that they are losing power in their marriage.', 'As in a waiting room, I sit.', ' I thought it might help my resume.', 'two liliaceous plants in particular erythronium grandiflorum and fritillaria pudica are marvelously beautiful and abundant', 'He was sorry about what was mainly a misunderstanding.', 'i have already explained others of his titles were', 'you know she must be attached to him i understand', 'we have a right to that tune now there was a moment of silence some of the people gasped as they had done when they saw tad waving the confederate flag at the window', 'She must pluck up courage and tell him.', 'withheld and may frustrate every psychotherapeutic influence where suspicion is awake and mere confidential talk and persuasion seem insufficient', 'Prayer is the celebration of this constant presence.', 'standing amazed with the blood running down to our heels my eldest sister being yet in the house and seeing those woeful sights the infidels hauling mothers one way and children another and some wallowing in their blood', ' Gaze long and hard at the stars in the night sky.', 'we lived together twenty years without any children her barrenness did not effect any change in my love i still treated her with much kindness and affection', 'The floor at the edge was stained a dark oak.', "‘Then I did hear them fire the gun last night!'", " I agree with that beauty contest has to be banned. In my opinion, the beauty contest never care about people's inner beauty.", "It's a long, but not hard, way to the top.", " They occasionally draw pictures of the boutique's latest fashions.", 'which ever it is joy of a spitfire and an honest woman said miss randolph wrathfully for the reference to conniston touched her n ...
# ('KR', 'KR', 'KR', 'US', 'KR', 'KR', 'US', 'KR', 'US', 'GB', 'GB', 'KR', 'GB', 'GB', 'KR', 'GB', 'KR', 'GB', 'US', 'GB', 'GB', 'GB', 'US', 'KR', 'GB', 'US', 'GB', 'KR', 'GB', 'US', 'GB', 'KR', 'KR', 'GB', 'US', 'US', 'KR', 'KR', 'US', 'GB', 'GB', 'US', 'US', 'US', 'KR', 'US', 'US', 'US', 'KR', 'US', 'KR', 'KR', 'GB', 'GB', 'GB', 'KR', 'US', 'KR', 'GB', 'US', 'KR', 'GB', 'GB', 'US') (' Fran found his complete dullness interesting.', " Please don't knock it until you've tried it.", ' I did. But I remembered I forgot to take the files I needed tomorrow.', 'the silent worker is imagination which decrees reality out of chaos without imagination what a poor thing my world would be', " but if you don't have tissue is somewhat complicated and Powerful of all the works of nature 12", ' Fashion was one means by which people competed with one another. ', "suddenly a light shone down into philip's mind his voice was changed as he spoke next", ' An accused person is presumed innocent until proven guilty.', 'a spirit already detached from the earth at the cry which broke from lorenzo dei medici when he saw him disappear', "‘I'm sorry if I was a bear this morning.'", 'You therefore have to address the question of ‘credit risk’.', ' For months, the packed main chamber and 12 overflow rooms in the 13th-century Justice Palace heard the harrowing accounts of the victims.', "She was quiet and didn't laugh very often.", 'Once more I sense the evil in our midst.', ' All they could see was the blue water surrounding their sailboat.', 'Mechanical equilibrium, for example, is a form of static equilibrium.', " I'm like wait on our childhood.", 'The argument ended and I went into the shop.', 'but the motion of the brig continued very heavy a large swell having been set running by the long fierce gale that was gone and there being no uproar of tempest in the sky to confound the senses', 'So he thought she was explosive, did he?', 'They are well able to collect their food for themselves.', "‘I said, as far as you want to go.'", 'knit those left at the end eighteenth row seamed make one at the beginning nineteenth row make one', ' We have a perfect apartment for you.', 'Still, it was only a hare that had hurt him.', "i want you to take sanch home and tell your mother i'm going to walk and may be won't be back till sundown miss celia said i might do what i pleased all day you remember now", 'I think this gave him a bit of heart.', ' I hope you find a partner who is honest, faithful, kind, and communicative with you. ', '‘How should I know?’ said Rose with a shrug.', 'i do not know why it should be so but i am compelled by something in my nature to want to serve this idea of a new age for mankind i want it as my culminating want i want a world in order', "It doesn't necessarily mean that you will be.", ' Others built huge burners with chimneys to deal with the problem.', ' Moreover, they had the same favorite movie, and both had a hobby of collecting antique furniture.', 'I say, still looking at the window.', 'on the delighted ferko but the two brothers had grown quite green with envy and only declared the more that ferko was nothing but a wicked magician', "romanianus divined her anxiety and hastened to set it at rest he had a house in carthage he said it should be augustine's as long as he required it", ' After all the berries were gone, it was bad luck to continue kissing under that bush.', ' I turned it in to the professor.', "look here put it under the bast matting and cover it with hay that's the way", "She didn't want his constant intrusion into her life.", "‘I've a job for you in the morning.’", 'section two for the better part of forty hours sir richmond had either been talking to miss grammont or carrying on imaginary conversations with her in her absence', 'and if you had been observing you would have known all this when i said the sheep would be wagging their tails behind them and then you would not have passed all those days in searching for wha ...
# ('US', 'US', 'US', 'US', 'KR', 'KR', 'US', 'KR', 'US', 'KR', 'US', 'GB', 'GB', 'US', 'KR', 'KR', 'US', 'GB', 'KR', 'GB', 'GB', 'KR', 'US', 'US', 'GB', 'GB', 'GB', 'US', 'US', 'GB', 'KR', 'US', 'US', 'KR', 'KR', 'US', 'KR', 'KR', 'KR', 'US', 'KR', 'US', 'US', 'GB', 'KR', 'GB', 'GB', 'GB', 'KR', 'GB', 'GB', 'GB', 'KR', 'KR', 'GB', 'US', 'US', 'GB', 'GB', 'KR', 'GB', 'GB', 'GB', 'KR') ('that trusted in his own strength and in his power and in his army and in his shields and in his chariots and in his horsemen not by fighting with the sword', 'i had no money all i had was nine roubles i had to give seven of that to my servant apollon for his monthly wages that was all i paid him he had to keep himself', 'by keeping it in gaol whence it shall have no help but him who being to it gave and to increase his mournful accident', "the forward violet thus did i chide sweet thief whence didst thou steal thy sweet that smells if not from my love's breath", ' Dear Jamie, I really like the drawing of the cute reindeer.', " What's your favorite fruit?", "that mohammed fled from mecca this event is very important in mohammedan history it is called the flight of the prophet or the hej'i ra", ' I check off each task on my list as soon as I complete it.', 'of human life of green life of life of any kind there was none', ' Emma was very conscious of this fatal weakness.', 'for victorian england and third empire france falsely proclaimed the representative quality of the official press to the honour of the socialist movement the socialist free press was the first to stand up as an equal against the giants', 'But we were afraid she might then escape.', "'He is not, I think, quite English?’", 'in three months kennicott made seven thousand dollars which was rather more than four times as much as society paid him for healing the sick in early summer began a campaign of boosting', ' Last week, the delivery driver who dropped off the sandwiches in record time.', ' When the boy moved away, Jill missed seeing him every morning.', "the vehicle drew nearer and at length stopped opposite the house on which polton slid down the stairs with the agility of a harlequin a few moments later i heard his voice ascending from the hall i do hope sir you're not much hurt", "'What should I want to take with me?’", ' In Finland, people must know how to read in order to get married.', "‘Don't you adopt that tone with me young woman.’", '‘How do you do?’ she said formally.', ' Also included are all other services necessary to support the universal service obligation.', 'and these spots are now indicated by heaps of shells in some places forming mounds of considerable size', "to ask why i hadn't had it painted i was too busy that morning to quarrel so i sent word that i would fix it up and when i was driving by there next day the painters were hard at work on it", "'Did he make it to a tree too?’", 'He tried to discourage her in every way.', 'Do you believe that anger is destructive?', "but d'artagnan did not stir", 'it was pleasant after that honour to return to the profane world of spectators amid nudges and significant looks then as to money he really had a great sum under his control', "'Frankly, I don't have much faith in the aunt.’", ' They have people understand who they were or where they came from and how they should be behave.', 'isabel thought this a better answer than she admitted it was a tolerable description of her own manner of judging but it would not have sounded well for her to say so', 'and now little bo peep no more did weep my tale of tails ends here', ' No one disputes that aggression, so tragically widespread among human beings, is also found among members of the animal kingdom. ', ' they have people understand who they work where they came from and how they should behave', 'on the pretext of engaging rooms for a friend the landlord was sorry but the house was full', ' These processes includerefrigeration, freezing, heat processing, and preserving with  ...
# ('US', 'US', 'GB', 'US', 'KR', 'GB', 'GB', 'KR', 'KR', 'GB', 'US', 'US', 'KR', 'KR', 'US', 'KR', 'GB', 'GB', 'KR', 'KR', 'KR', 'GB', 'GB', 'US', 'US', 'GB', 'GB', 'US', 'US', 'KR', 'US', 'KR', 'GB', 'GB', 'US', 'KR', 'US', 'US', 'GB', 'US', 'GB', 'GB', 'KR', 'KR', 'GB', 'KR', 'KR', 'US', 'US', 'KR', 'US', 'GB', 'GB', 'GB', 'US', 'US', 'US', 'GB', 'KR', 'GB', 'US', 'US', 'KR', 'US') ("hence the driver's hope of finding them in the rue de bourgogne", 'and the neighbors would say to each other in a low voice', 'I knew her better than anyone but the king.', 'there was not a foot of free ground the bushes seemed absolutely impenetrable as indeed they were later found to be when we halted the men sat', " The star-crossed lovers came to grips with the fact that their boundless love won't be realized without cost.", '‘We meet again,’ he said with a grin.', '‘I know it like the back of my hand.’', ' Storytelling and arts comes in many foods.', " I don't miss anybody from my childhood.", "‘It might just work, for a while.'", 'rachel spoke with the frankness that had always existed between the two friends jasper chase told me the other night that he in fact he proposed to me or he would if', "and of the birth and baptism of her child after a few words more i took my departure the hour she named having nearly arrived at the porter's lodge i met the marquis ossoli", ' Klaus failed his French test.', ' Also included that other service is supported the United States obligations.', 'the breakfast hour arrived', " No worries, let's resure the rest.", 'Alcoholism is an illness that needs urgent treatment.', 'One is to conclude that all is well.', ' Meanwhile, the test subjects from the second group felt overwhelmed and discouraged.', ' I play games on weekend sometimes when a friend asked to play I go out and play', ' The nation has been under the control of the United Kingdom since 1818.', 'Yes, he thought, and what brought you here to me?', 'He was speaking with sham formality again.', 'and was averse to war in the dutch republic the states party especially in holland the chief sufferer by the war was anxious for a cessation of hostilities and it found its leader in the youthful john de witt', 'this is the view that the governor so admired and tradition tells us', 'There was a certain defiance in his tone.', 'She ran a hand through her hair.', 'or bid it meet thee this day in paradise i ask not not in a wish not in a thought infirmity of nature curiosity of mind are temptations that offer', 'and so might marry again when he would', ' We can infer from the underlined part that a great many fans will come to the concert.', 'even those persons whom the child seems to love from the very beginning it loves at the outset because it has need of them cannot do without them in others words out of egoistical motives', ' The choir practices the song Sunday mornings.', "‘I didn't mean in the medical sense.'", 'Her voice was deadly calm as she spoke.', 'was considered a good one three days later in crossing over a lonely region near the nebraska national forest farley munson which was one of the names the spy went by', ' In the center of the village, stood a curious monument.', "and holding the dignified major in loving regard was glad to cross swords with him now and then to add variety to their pleasant relations it's this way major doyle he now remarked coolly", 'they sprang from him herschel attributed their brilliancy to currents of lava congealed by the cold an opinion however which has not been generally adopted', "‘I don't need a doctor to tell me that.'", 'and to do so had not only drained the treasury but imposed some new and unwise taxes on the harassed provincials and disbanded many of his veterans for the sake of economy', "‘I couldn't believe it when the letter came,’ she said.", 'All they need is the support of the West.', ' All the sweat and aching muscles become worth it to experience that feeling of accomplishment.', ' Did you have a lon ...
# ('US', 'US', 'KR', 'KR', 'KR', 'KR', 'KR', 'KR', 'KR', 'GB', 'KR', 'KR', 'US', 'KR', 'KR', 'US', 'US', 'US', 'KR', 'KR', 'US', 'KR', 'GB', 'KR', 'KR', 'US', 'GB', 'KR', 'KR', 'KR', 'GB', 'KR', 'US', 'GB', 'US', 'KR', 'US', 'KR', 'KR', 'KR', 'KR', 'GB', 'US', 'US', 'GB', 'KR', 'KR', 'KR', 'US', 'US', 'GB', 'US', 'GB', 'US', 'US', 'US', 'US', 'US', 'US', 'GB', 'GB', 'US', 'GB', 'GB') ('and all apamea and all mesopotamia', "you are a bad old rascal to steal eggs what's more", ' Every engineer strives to incorporate the best elements from all the proposed plans.', ' You have to submit it till next Monday.', " It's more like a brisk walk with detours along the way.", ' Goodyear named his process of heating rubber and sulfur "vulcanization," after Vulcan, the Roman god of fire.', ' I prefer to go to school rather than go to the slumber party.', ' The obstinate refuse to change course even when it is clear they are headed in the wrong direction.', ' The stoic philosophers believed that divine principles of the universe can ultimately reveal the essential reasons for and virtues of human life. ', 'She was waiting for a boat, you understand.', ' Do you prefer classical music to rock music?', ' Remove the outer leaves of leafy vegetables.', 'for the purpose of meeting immediate exigencies had never been deliberately revised and perfected in a time of tranquillity every one of the seven commonwealths', " Herald had accidentally hacked into his company's server.", " The star-crossed lovers came to grips with the fact that their boundless love won't be realized without cost.", 'i shall never win her lady julia as he spoke these last words the tears were running down his cheeks', 'then he returned to the rocks against which the furious waves were beating to save what he could i was unable to speak i was shattered with fatigue and excitement', 'said the bear licking his paws that is all the shade you can give against the sun if you are not pleased with me you can go answered the oak proudly', ' I think ten dollars are too expensive to have a medical treatment.', ' After eating his sandwich in record time, Jackie dipped into his bag for a second one.', 'in which were a pair of wooden shoes above the shoes was a card saying simply', ' No. It close on winter season because of the safety reason.', 'So he would soon be gone, would he?', ' It helps the community save many turtle eggs from being taken illegally.', ' His show was grounded in real-life styles with a lot of utilitarian knee-length shorts, cargo trousers, and relaxed knitwear.', 'his patient smiled as he gently repulsed his physician in an attempt to undo the bandages and with a returning glow to his cheeks inquired', "It's really rather clever when you think about it.", ' The pupil brought a lovely gift for her Sunday school teacher.', ' Her eyes ran over the list to see if her name was on it.', ' The "D.C." in Washington D.C. is short for the District of Columbia.', 'The first reaction is to startle, the second to bolt.', ' Susie often sings when she race up her shoes.', "lawd honey yo needn't have no punctions bout takin dis yer book", 'Usually each main point has at least one important detail.', 'the juniors will get the reputation among the teachers this year that the junior class had last and it seems such a pity i overheard miss chester tell miss kane the other day', " I agree if weather gets cold people don't buy bicycles.", 'rachel looked at virginia thoughtfully i have never given my heart to him i am sure he touched my emotions and i admired his skill as a writer i have thought at times that i cared a good deal for him', ' A woman receives a parcel from internet shopping. She is very satisfied with the red clothes on her body.', ' He washed the dishes with lukewarm water.', ' I play tennis once or twice a week.', ' They help people understand who they were, where they came from, and how they should behave.', 'Time is of little consequence out here.', 'opened the movable pane ...
# ('US', 'KR', 'GB', 'GB', 'KR', 'GB', 'US', 'US', 'KR', 'KR', 'US', 'KR', 'GB', 'US', 'KR', 'US', 'KR', 'GB', 'KR', 'KR', 'US', 'US', 'GB', 'KR', 'US', 'GB', 'GB', 'GB', 'GB', 'US', 'KR', 'GB', 'US', 'US', 'US', 'GB', 'KR', 'KR', 'US', 'GB', 'GB', 'KR', 'US', 'US', 'KR', 'KR', 'GB', 'GB', 'GB', 'GB', 'GB', 'US', 'GB', 'GB', 'GB', 'KR', 'US', 'US', 'US', 'KR', 'GB', 'US', 'KR', 'GB') ('and had sent that mild mannered observer into the harbor to investigate into the state of affairs', ' is it better to go to customer service center hurry up', 'Perhaps he could pick up someone new today.', 'The most precious possession he had was time.', ' Prayers are great blessings for people.', 'The cherry on the cake, though, is the price.', 'guests felt that they were receiving not conferring a favor when they stayed at her house even the smartest traveling men were flattered when missus gardener stopped to chat with them for a moment', 'any one who had seen us leaving the house to go on the river in the charming little boat which i had bought would never have believed that the woman dressed in white wearing a straw hat', ' Ministry shall take the necessary measures to protect the confidentiality of the information that is obtained while applying the Implementing Regulation.', ' After pleading no contest by telephone from New York, the former member of the Supremes was also fined $852.', 'uncle roger unlocked and flung open the front door as he did so clear and sweet rang out ten bell like chimes', ' The philosopher had a tendency to use overly exaggerated perspectives.', 'But Reality Orientation needs to be done with care.', 'and to lead him to bethulia', ' Getting up at dawn is for the birds.', "working himself captain nemo passed near me just then i touched him with my hand and pointed to the walls of our prison the starboard wall had moved forward to a point less than four meters from the nautilus's hull", ' The menu had both chicken and pork cutlets.', "'I remember your saying it a long time ago.’", ' New apartment complexes must now be built with proper building materials so that heat will not escape during the winter. ', ' I think you can disappear in about an hour', 'we all know that governors and other men of mark have proclaimed themselves descendants of pocahontas i have met several in the west and south', "how can you say such things she remonstrated well said the young man if you're born on the wrong side of the wall i can't see that it's wrong to climb over it", 'He had to see what was up with the sheep.', ' couple of minutes later the court clerk shows that film outlining what will happen throughout the day', 'the operation is so unique and singular that though after long years this child should have come to be an old man instead of a child and his black locks should have turned white', 'There was the glimmer of a smile.', 'I just have a bad feeling about him.', "'This is neither the time nor the place.’", 'You were offering a job, and I took it.', 'carbineer if the same to you master said the other quietly i never served in the infantry', ' We will now examine and trace the history of these controversies.', '"I was beginning to think you weren\'t coming."', 'or the way he looked at her i feel as if he is up to some of his tricks again', 'truer nobler then poverty has been riches failure has been a success if wealth has come to me and has made me vain arrogant contemptuous uncharitable cynical', 'who has full charge of the horses the other a coachman of sable skin yclept pluto poindexter who would scorn to look at a horse except when perched upon the box', 'I thought it was just a bang on the head.', ' Politics often pit the rural, agrarian interests against the urban interests.', " The beetle only wants to go where it won't be disturbed.", 'homer would construct the iliad he would put in his poem', 'It was quite a hard act to follow, believe me.', "Catching her up, he said, ‘You may want help.'", ' Jin was something I never dr ...
# ...
# ('US', 'GB', 'US', 'KR', 'US', 'GB', 'US', 'KR', 'KR', 'US', 'US', 'GB', 'GB', 'GB', 'US', 'KR', 'US', 'GB', 'KR', 'GB', 'GB', 'US', 'US', 'US', 'GB', 'US', 'GB', 'US', 'US', 'US', 'KR', 'KR', 'KR', 'GB', 'GB', 'KR', 'US', 'US', 'KR', 'KR', 'GB', 'US', 'US', 'GB', 'KR', 'US', 'KR', 'US', 'US', 'GB', 'US', 'US', 'GB', 'US', 'KR', 'US', 'KR', 'KR', 'GB', 'US', 'KR', 'GB', 'US', 'KR') ("pod didn't say anything though but just forked it on to the platter and scraped off some dry grass and a sliver and a bug and carved it up", 'There is no routine way to make profit.', 'having become the stand by of the newspaper the large advertiser', " The fact that there's a stairway to heaven and a highway to hell explains life well.", 'once in ohio several lads were collected together about a spring one of them drew a pail of fresh water and by chance brought up a small live fish', 'That is a considerable sacrifice of parliamentary power.', 'proof all the modes in which any given body is affected', ' In this way, the beverage does not touch your teeth.   ', " The architect didn't want to adopt the current trend of subtle, soft minimalism.", 'that i would have another calf to sacrifice and not that she used all her endeavours to persuade me to change my resolution but i continued firm', "there hasn't been a single word about it mentioned until you pushed your way in just now", 'Good news was the decision to build a replacement.', 'All day, his mind swam in a dreamy haze.', 'But when he was in this mood, fear came.', "and having taken a taste of every thing she was about to leave when she heard the stableman coming and in her fright couldn't find the hole so flew into the meal bin and hid herself", ' In the picture, there is a person who preparing travel. In a travel backpack, there are clothes, hat and shoes.', 'well versed in the theory of classification he was poorly versed in its practical application and i doubt that he could tell a sperm whale from a baleen whale and yet what a fine gallant lad', 'No charge will be made for attendance at this seminar.', ' My mom goes to the fortune teller from time to time.', 'Later a transcript will be read to the inquest.', 'He did know what he was, and he was different.', 'he came up into the garden and established himself under a burdock and began to practise italian scales the result was that poor old doctor bullfrog instead of being considered as a respectable old bore', 'it is an atmosphere not corrupted by my presence she said sharply', 'and by damming it those old settlers made a pond in which they could build their houses they had ideas of their own as to what a house should be like', "Far as I know, he's still there.", 'he publishes a letter from another correspondent who apologizes for opposing so high an authority as doctor gray but says that he had obtained some of these fishes from persons who lived at a considerable distance apart', 'So I said I would teach it to him.', 'all the boys were grown up and done for by this time so it is scarcely worth while saying anything more about them you may see the twins and nibs and curly any day going to an office each carrying a little bag and an umbrella', 'all round new little beech trees shot up which grew just as fast as their parents and looked as green and as happy as if they did not know what an uneasy conscience was', 'that said coronel simply is much more surprising merriwig however was not so sure of that he liked the look of coronel he liked his manner', ' Let us sing a song for Sarah.', ' Wanda wondered if she looked the same way.', ' The owner and the dog are interacting with each other.', 'Do you hear what you are saying?', "'Red flag for a hit, white for a miss.’", ' One successful entrepreneur paid for his parents to move into a luxury condominium out of filial obligation.', 'the young man may become lord chancellor or at any rate earn his bread comfortably as a county court judge but the girl can look forward to little else than the cha ...
# ('US', 'US', 'GB', 'GB', 'US', 'KR', 'GB', 'US', 'US', 'GB', 'GB', 'GB', 'GB', 'US', 'KR', 'GB', 'KR', 'GB', 'GB', 'GB', 'US', 'KR', 'US', 'US', 'US', 'KR', 'GB', 'US', 'GB', 'GB', 'GB', 'US', 'GB', 'GB', 'KR', 'KR', 'GB', 'US', 'US', 'US', 'US', 'KR', 'US', 'US', 'GB', 'US', 'US', 'GB', 'GB', 'GB', 'GB', 'KR', 'KR', 'US', 'KR', 'GB', 'US', 'KR', 'GB', 'KR', 'US', 'GB', 'GB', 'US') ('either by way of attack or defense that they must be conversing about any other subject than of love at the end of the conversation the lady rose and bowed profoundly to aramis', 'and from there to the northwestern university where he was graduated from the medical department all this time although receiving some aid from various sources he largely supported himself', "'I do a clinic there once a week.’", "Car oil, so I've been told, is their tipple.", 'who does not need the strong religious reenforcement of the suggestion because he reenforces instead the suggestibility of the patient by slight influences on his senses', ' The last train to Cincinnati will leave in a minute.', 'They could have come from anyone, anywhere.', 'there are a few instances as in the case of the ghost baby mentioned later but very few ancient ghosts were a long faced lot', 'own taste the best isabelle clara rosalind eleanor were all american eleanor would pitch probably southpaw rosalind was outfield wonderful hitter clara first base maybe', 'The industry has a booming though fragile market to protect.', '‘Could you not consider leaving the room?’', '‘If I went to his house, I might see him.’', "‘It won't rain,’ she said in assurance.", 'by falling in love with a popish clergy woman said trim twas a beguine said my uncle toby doctor slop was too much in wrath to listen to the distinction', ' Captain Joy pat on the garden open the pet cat hat.', 'There again, he might just be shy?', ' My personal trainer is really careful about what he eats. ', "He wasn't the great love of my life.", 'The term ‘mixed race’ is also inaccurate.', 'The officer concerned would be subject to internal army discipline.', 'when they had revolted from the way which god had given them to walk therein they were destroyed in battles by many nations and very many of them were led away captive', ' Please refrain from talking in crowded places, such as the elevator.', 'missus collingwood however shook her head when joyce announced who was outside i do not remember any one named calthorpe and i scarcely feel that i can see a stranger now', 'will not really lessen very much the awful condition at the rectangle as long as the saloon is legally established there i think that is true of any christian work now being carried on in any great city', "wonder what humbird's body looked like now if he himself hadn't been bayonet instructor he'd have gone up to line three months sooner probably been killed where's the darned bell", ' Sit down and cross your legs, please!', "‘No, but then other people would know.'", 'my god he cried in later years with what bitter gall didst thou in thy great mercy sprinkle those pleasures of mine he could not forget', 'A brief letter or comment will do.', '‘But maybe she will go outside the tribe.’', 'I felt so rotten I said nothing.', 'well well said emily impatiently and anxious to enquire on another subject', 'And what he would do in return.', "'Come here and give us a kiss!’", ' Whether it’s before or after breakfast, light physical activity within an hour or two after awakening also helps to increase your metabolism throughout the day.', ' The device emits a beeping sound when its battery is low.  ', 'We have already met one other molar constant.', 'when it was understood that he had written to his new mother on the occasion for a few days every morning visit in highbury included some mention of the handsome letter missus weston had received', 'ah ah thought the smiling clerk in a flutter of delight this is something new but as these little diversions never made him forget his  ...
# ('GB', 'GB', 'GB', 'GB', 'GB', 'GB', 'GB', 'US', 'GB', 'GB', 'KR', 'GB', 'GB', 'US', 'GB', 'US', 'KR', 'US', 'GB', 'GB', 'US', 'US', 'KR', 'KR', 'GB', 'KR', 'US', 'KR', 'KR', 'US', 'GB', 'US', 'US', 'US', 'KR', 'US', 'US', 'KR', 'US', 'GB', 'GB', 'GB', 'US', 'US', 'KR', 'KR', 'US', 'KR', 'KR', 'US', 'GB', 'GB', 'US', 'KR', 'KR', 'US', 'US', 'KR', 'GB', 'KR', 'US', 'US', 'GB', 'US') ("‘It did shake me up, but I'm over it now.’", 'Was there any reason for this long absence?', 'What is it you want of me?', "He didn't even bother to look at him.", 'Outside, in the open air, it was glorious.', "I'm in close touch with my uncle.", "'Anything to get my practice, in fact.’", 'but dear emma was of no feeble character', 'She sat up straight, feeling proud but rather foolish.', 'The texture of it is light but too soft.', ' The mathematician was able to detect an error in the equation.', "‘I don't suppose you remember where they are, do you?’", 'It was just like the first one.', 'applies to that which has to be fashioned bruised forged stretched roasted annealed refined', 'The contract was made at the reception desk.', 'but in the name of heaven do not tremble so it is impatience parry come what did the general say to you at first the general would not receive me', ' However, this common image represents only a brief phase in the newt’s life cycle. ', 'peter sees rosebreast and finds redcoat', '‘I tried to tell her that,’ he said.', '‘Then why do you want to talk to me?’', 'and i have often boasted that i obtained them all looking back over half a century', "feed him grain no you won't put him up i'll tend to that looks like a bad un that's it", ' he has a product. He can grow anything in his garden', ' Although the author seemingly tries to accept her present situation, she still desires to be free.', 'Everyone felt that history was being made.', ' During revising, you review and refine content and structures.', "like birds but they were now for the most part black creatures who flapped their wings drearily near to the ground and refused to rise on any wings of hope the men's faces grew doleful from the interpreting of omens", ' Would you like a couple of onion bagels?', ' The rescue workers went above and beyond in their search for the missing children.', 'i bought her said jeff at thirty two and she stayed right there tight like she was stuck', '‘I left a coin for the executioner.’', 'he will be back to dinner will he not if the volor is not late now mother are you ready for breakfast mabel passed an afternoon of considerable agitation it was certain that something had happened', 'and his favourite headgear was a faded hat battered out of shape by the rain', "at last he had got into something that he took an interest in spending money and he just fairly wallowed in it used to lay awake nights thinking up new ways of getting rid of the old man's profits", ' How do you celebrate Easter?', 'when the princes understood whither the argonauts were going they offered to turn back and guide them to colchis', 'all the capacities of a daring and skillful soldier', ' Liam accepted his responsibility to meet the deadline.', 'jim made two trips without selling enough to keep them working overtime at the factory and then he came into my office with a long story about how we were doing it all wrong said we ought to go for the consumer by advertising', 'I was in a state of shock.', "I won't go into all the story.", 'The fragrant steam made his mouth water.', "shortly the advance party reached sutter's fort where they received the most hospitable treatment", 'through the glass top he had just caught sight of a figure that seemed familiar he had seen that tweed before the short girl with her back to him was wearing the dress in which he had seen her on the wednesday night', ' This is the last random sentence I will be writing and I am going to stop mid-sent.', ' My ex is with another man.', 'and it took place to the infinite mortification of mister and  ...
# ('GB', 'KR', 'KR', 'KR', 'US', 'GB', 'GB', 'US', 'GB', 'GB', 'GB', 'GB', 'US', 'US', 'GB', 'KR', 'KR', 'KR', 'GB', 'GB', 'GB', 'US', 'KR', 'US', 'KR', 'KR') ('His Mum and Dad would see him.', ' Perhaps 90 percent of the time, when you encounter the word "abject" it will be followed by the word "poverty."', ' Being curious is when you have a strong desire to know about something.', ' The thief had nimble fingers as well as an acute sense of hearing.', 'remember though that it is your doing not mine but you cannot think i am going to see you starve isabel a sum we will fix upon the amount amicably', '‘Did you try to prevent the marriage?’', "How strange, he thought, I'm not tired at all.", 'and six stewpots that stood round the blaze had not been made in the ordinary mould of common pots for they were six half wine jars each fit to hold the contents of a slaughter house', "'Don't try and play the innocent with me!’", 'I howl, and I throw myself down on the floor.', "‘I don't think it was silly, Johnny.'", 'How could you hurt me like that?', 'his eyes studying the fire his fingers on the chair arm were restless doctor groom stood at the foot of the stairs talking with the clergyman a stout and unctuous figure', 'existed in the city of new amsterdam this is but a lofty and gigantic mode in which we heroic writers always talk of war thereby to give it a noble and imposing aspect', "Even if it isn't, he thought, she can't bite me!", ' According to the chart, the patients multiple referred contact was the phone at 69.4% and the video conference was the lowest.', " The business's profits for this year exceeded that of last year's by $16,000. ", ' Her trainer was even more gloomy about the prospects for British tennis.', '‘What are they doing?’ he said to the landlord.', 'A crucial decision must be made without hesitation.', "‘Think once more, Harry, before I go.'", 'but it was all preaching in the desert and hammering cold iron nevertheless among many other representations made to him the housekeeper said to him in truth master if you do not keep still and stay quiet at home', ' When you learn, you get knowledge or a skill through studying.', 'but as soon as missus roby was gone and missus roby went home round the corner somewhat earlier than usual then mister wharton woke up instantly and made inquiry of his daughter', ' The participants ranged in age from 37 to 73 years old and reported they had no cardiovascular disease or cancer at the time of the survey.', ' The findings of a new study underscored how sensitive our bodies are to different types of exercise.')
